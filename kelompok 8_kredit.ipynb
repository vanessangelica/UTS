# %% [markdown]
# # Kelompok 8 (Algoritma dan Struktur Data)
#
# Anggota:
#    - Amelia Nur Humairoh (2208541016)
#    - Ni Kadek Wulanda Asmara Santhi (2208541017)
#    - Nur Hikmah (2208541019)
#    - Vanessa Angelica Heriyanto (2208541029)

# %% [markdown]
# # Memanggil data dengan link dan nama file

# %%
#sebelum memulai mengolah data pertama yang kita lakukan import dulu library-library yang akan digunakan 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#memanggil data dengan menggunakan link
train = pd.read_csv('https://raw.githubusercontent.com/imdwipayana/DATA/main/Dataset%20Final%20Project%202023/Kredit/train.csv')
train.head()
# Out:
# C:\Users\62878\AppData\Local\Temp\ipykernel_6480\147080156.py:2: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv('https://raw.githubusercontent.com/imdwipayana/DATA/main/Dataset%20Final%20Project%202023/Kredit/train.csv')
#        ID Customer_ID     Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0      19114.12            1824.843333                  3  ...           _
# 1      19114.12                    NaN                  3  ...        Good
# 2      19114.12                    NaN                  3  ...        Good
# 3      19114.12                    NaN                  3  ...        Good
# 4      19114.12            1824.843333                  3  ...        Good
#
#    Outstanding_Debt Credit_Utilization_Ratio     Credit_History_Age  \
# 0            809.98                26.822620  22 Years and 1 Months
# 1            809.98                31.944960                    NaN
# 2            809.98                28.609352  22 Years and 3 Months
# 3            809.98                31.377862  22 Years and 4 Months
# 4            809.98                24.797347  22 Years and 5 Months
#
#    Payment_of_Min_Amount Total_EMI_per_month Amount_invested_monthly  \
# 0                     No           49.574949       80.41529543900253
# 1                     No           49.574949      118.28022162236736
# 2                     No           49.574949         81.699521264648
# 3                     No           49.574949       199.4580743910713
# 4                     No           49.574949      41.420153086217326
#
#                   Payment_Behaviour     Monthly_Balance Credit_Score
# 0   High_spent_Small_value_payments  312.49408867943663         Good
# 1    Low_spent_Large_value_payments  284.62916249607184         Good
# 2   Low_spent_Medium_value_payments   331.2098628537912         Good
# 3    Low_spent_Small_value_payments  223.45130972736786         Good
# 4  High_spent_Medium_value_payments  341.48923103222177         Good
#
# [5 rows x 28 columns]

# %%
#memanggil data dengan nama file
train = pd.read_csv('train.csv')
train.head()
# Out:
# C:\Users\62878\AppData\Local\Temp\ipykernel_6480\2830169800.py:2: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv('train.csv')
#        ID Customer_ID     Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0      19114.12            1824.843333                  3  ...           _
# 1      19114.12                    NaN                  3  ...        Good
# 2      19114.12                    NaN                  3  ...        Good
# 3      19114.12                    NaN                  3  ...        Good
# 4      19114.12            1824.843333                  3  ...        Good
#
#    Outstanding_Debt Credit_Utilization_Ratio     Credit_History_Age  \
# 0            809.98                26.822620  22 Years and 1 Months
# 1            809.98                31.944960                    NaN
# 2            809.98                28.609352  22 Years and 3 Months
# 3            809.98                31.377862  22 Years and 4 Months
# 4            809.98                24.797347  22 Years and 5 Months
#
#    Payment_of_Min_Amount Total_EMI_per_month Amount_invested_monthly  \
# 0                     No           49.574949       80.41529543900253
# 1                     No           49.574949      118.28022162236736
# 2                     No           49.574949         81.699521264648
# 3                     No           49.574949       199.4580743910713
# 4                     No           49.574949      41.420153086217326
#
#                   Payment_Behaviour     Monthly_Balance Credit_Score
# 0   High_spent_Small_value_payments  312.49408867943663         Good
# 1    Low_spent_Large_value_payments  284.62916249607184         Good
# 2   Low_spent_Medium_value_payments   331.2098628537912         Good
# 3    Low_spent_Small_value_payments  223.45130972736786         Good
# 4  High_spent_Medium_value_payments  341.48923103222177         Good
#
# [5 rows x 28 columns]

# %%
#bertujuan untuk mengecek ukuran dataset yang kita gunakan
train.shape
# Out:
# (100000, 28)

# %%
#untuk melihat isi dari kolom yang tertera pada dataset.
train.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
#untuk menampilkan statistik deskriptif pada dataset
train.describe()
# Out:
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# count           84998.000000      100000.000000     100000.00000
# mean             4194.170850          17.091280         22.47443
# std              3183.686167         117.404834        129.05741
# min               303.645417          -1.000000          0.00000
# 25%              1625.568229           3.000000          4.00000
# 50%              3093.745000           6.000000          5.00000
# 75%              5957.448333           7.000000          7.00000
# max             15204.633333        1798.000000       1499.00000
#
#        Interest_Rate  Delay_from_due_date  Num_Credit_Inquiries  \
# count  100000.000000        100000.000000          98035.000000
# mean       72.466040            21.068780             27.754251
# std       466.422621            14.860104            193.177339
# min         1.000000            -5.000000              0.000000
# 25%         8.000000            10.000000              3.000000
# 50%        13.000000            18.000000              6.000000
# 75%        20.000000            28.000000              9.000000
# max      5797.000000            67.000000           2597.000000
#
#        Credit_Utilization_Ratio  Total_EMI_per_month
# count             100000.000000        100000.000000
# mean                  32.285173          1403.118217
# std                    5.116875          8306.041270
# min                   20.000000             0.000000
# 25%                   28.052567            30.306660
# 50%                   32.305784            69.249473
# 75%                   36.496663           161.224249
# max                   50.000000         82331.000000

# %% [markdown]
# # Mengetahui Jenis Data

# %%
#untuk mengetahui data nya berupa integer,data kategori atau bilangan desimal.
train.dtypes
# Out:
# ID                           object
# Customer_ID                  object
# Month                        object
# Name                         object
# Age                          object
# SSN                          object
# Occupation                   object
# Annual_Income                object
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                  object
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment       object
# Changed_Credit_Limit         object
# Num_Credit_Inquiries        float64
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Credit_History_Age           object
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly      object
# Payment_Behaviour            object
# Monthly_Balance              object
# Credit_Score                 object
# dtype: object

# %% [markdown]
# # Mengecek apakah ada data yang kosong

# %%
#untuk mengetahui jumlah data yang kosong 
train.isnull().sum()
# Out:
# ID                              0
# Customer_ID                     0
# Month                           0
# Name                         9985
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       15002
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                11408
# Delay_from_due_date             0
# Num_of_Delayed_Payment       7002
# Changed_Credit_Limit            0
# Num_Credit_Inquiries         1965
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           9030
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4479
# Payment_Behaviour               0
# Monthly_Balance              1200
# Credit_Score                    0
# dtype: int64

# %%
#untuk mengecek data yang kosong
train.isna()
# Out:
#           ID  Customer_ID  Month   Name    Age    SSN  Occupation  \
# 0      False        False  False  False  False  False       False
# 1      False        False  False  False  False  False       False
# 2      False        False  False  False  False  False       False
# 3      False        False  False  False  False  False       False
# 4      False        False  False  False  False  False       False
# ...      ...          ...    ...    ...    ...    ...         ...
# 99995  False        False  False  False  False  False       False
# 99996  False        False  False  False  False  False       False
# 99997  False        False  False  False  False  False       False
# 99998  False        False  False  False  False  False       False
# 99999  False        False  False  False  False  False       False
#
#        Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0              False                  False              False  ...
# 1              False                   True              False  ...
# 2              False                   True              False  ...
# 3              False                   True              False  ...
# 4              False                  False              False  ...
# ...              ...                    ...                ...  ...
# 99995          False                  False              False  ...
# 99996          False                  False              False  ...
# 99997          False                  False              False  ...
# 99998          False                  False              False  ...
# 99999          False                  False              False  ...
#
#        Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 0           False             False                     False
# 1           False             False                     False
# 2           False             False                     False
# 3           False             False                     False
# 4           False             False                     False
# ...           ...               ...                       ...
# 99995       False             False                     False
# 99996       False             False                     False
# 99997       False             False                     False
# 99998       False             False                     False
# 99999       False             False                     False
#
#        Credit_History_Age  Payment_of_Min_Amount  Total_EMI_per_month  \
# 0                   False                  False                False
# 1                    True                  False                False
# 2                   False                  False                False
# 3                   False                  False                False
# 4                   False                  False                False
# ...                   ...                    ...                  ...
# 99995               False                  False                False
# 99996               False                  False                False
# 99997               False                  False                False
# 99998               False                  False                False
# 99999               False                  False                False
#
#        Amount_invested_monthly  Payment_Behaviour  Monthly_Balance  \
# 0                        False              False            False
# 1                        False              False            False
# 2                        False              False            False
# 3                        False              False            False
# 4                        False              False            False
# ...                        ...                ...              ...
# 99995                    False              False            False
# 99996                    False              False            False
# 99997                    False              False            False
# 99998                    False              False            False
# 99999                    False              False            False
#
#        Credit_Score
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ...             ...
# 99995         False
# 99996         False
# 99997         False
# 99998         False
# 99999         False
#
# [100000 rows x 28 columns]

# %% [markdown]
# # Menghilangkan Kolom

# %%
train = train.drop(['ID','Customer_ID','Name','SSN','Type_of_Loan','Credit_History_Age','Credit_Mix'],axis=1)

# %%
#memanggil data dengan ukuran yang sedikit dimulai dari urutan paling atas
train.head()
# Out:
#       Month   Age Occupation Annual_Income  Monthly_Inhand_Salary  \
# 0   January    23  Scientist      19114.12            1824.843333
# 1  February    23  Scientist      19114.12                    NaN
# 2     March  -500  Scientist      19114.12                    NaN
# 3     April    23  Scientist      19114.12                    NaN
# 4       May    23  Scientist      19114.12            1824.843333
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                  3                4              3           4
# 1                  3                4              3           4
# 2                  3                4              3           4
# 3                  3                4              3           4
# 4                  3                4              3           4
#
#    Delay_from_due_date  ... Changed_Credit_Limit Num_Credit_Inquiries  \
# 0                    3  ...                11.27                  4.0
# 1                   -1  ...                11.27                  4.0
# 2                    3  ...                    _                  4.0
# 3                    5  ...                 6.27                  4.0
# 4                    6  ...                11.27                  4.0
#
#    Outstanding_Debt Credit_Utilization_Ratio  Payment_of_Min_Amount  \
# 0            809.98                26.822620                     No
# 1            809.98                31.944960                     No
# 2            809.98                28.609352                     No
# 3            809.98                31.377862                     No
# 4            809.98                24.797347                     No
#
#   Total_EMI_per_month  Amount_invested_monthly  \
# 0           49.574949        80.41529543900253
# 1           49.574949       118.28022162236736
# 2           49.574949          81.699521264648
# 3           49.574949        199.4580743910713
# 4           49.574949       41.420153086217326
#
#                   Payment_Behaviour     Monthly_Balance Credit_Score
# 0   High_spent_Small_value_payments  312.49408867943663         Good
# 1    Low_spent_Large_value_payments  284.62916249607184         Good
# 2   Low_spent_Medium_value_payments   331.2098628537912         Good
# 3    Low_spent_Small_value_payments  223.45130972736786         Good
# 4  High_spent_Medium_value_payments  341.48923103222177         Good
#
# [5 rows x 21 columns]

# %% [markdown]
# # Menghilangkan Data yang berisi NaN

# %%
#untuk menghilangkan data NaN
train = train.dropna()

# %%
#untuk menampilkan 
train.head()
# Out:
#       Month  Age Occupation Annual_Income  Monthly_Inhand_Salary  \
# 0   January   23  Scientist      19114.12            1824.843333
# 6      July   23  Scientist      19114.12            1824.843333
# 7    August   23  Scientist      19114.12            1824.843333
# 8   January  28_    _______      34847.84            3037.986667
# 9  February   28    Teacher      34847.84            3037.986667
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                  3                4              3           4
# 6                  3                4              3           4
# 7                  3                4              3           4
# 8                  2                4              6           1
# 9                  2                4              6           1
#
#    Delay_from_due_date  ... Changed_Credit_Limit Num_Credit_Inquiries  \
# 0                    3  ...                11.27                  4.0
# 6                    3  ...                11.27                  4.0
# 7                    3  ...                11.27                  4.0
# 8                    3  ...                 5.42                  2.0
# 9                    7  ...                 7.42                  2.0
#
#    Outstanding_Debt Credit_Utilization_Ratio  Payment_of_Min_Amount  \
# 0            809.98                26.822620                     No
# 6            809.98                22.537593                     No
# 7            809.98                23.933795                     No
# 8            605.03                24.464031                     No
# 9            605.03                38.550848                     No
#
#   Total_EMI_per_month  Amount_invested_monthly  \
# 0           49.574949        80.41529543900253
# 6           49.574949        178.3440674122349
# 7           49.574949       24.785216509052056
# 8           18.816215         104.291825168246
# 9           18.816215        40.39123782853101
#
#                   Payment_Behaviour     Monthly_Balance Credit_Score
# 0   High_spent_Small_value_payments  312.49408867943663         Good
# 6    Low_spent_Small_value_payments   244.5653167062043         Good
# 7  High_spent_Medium_value_payments  358.12416760938714     Standard
# 8    Low_spent_Small_value_payments  470.69062692529184     Standard
# 9   High_spent_Large_value_payments   484.5912142650067         Good
#
# [5 rows x 21 columns]

# %% [markdown]
# # Mengubah Data Categorical ke Numerik

# %%
train.Credit_Score.unique()
# Out:
# array(['Good', 'Standard', 'Poor'], dtype=object)

# %%
train['Credit_Score'] = \
train['Credit_Score'].map({'Poor':0,'Standard':1,'Good':2})

# %%
#untuk memanggil data lebih sedikit dari urutan diaatas dengan baris urutan 0 - 19
train.head(20)
# Out:
#     Month Age  Occupation Annual_Income  Monthly_Inhand_Salary  \
# 0       0  23         0.0      19114.12            1824.843333
# 6       6  23         0.0      19114.12            1824.843333
# 7       7  23         0.0      19114.12            1824.843333
# 17      1  34         3.0     143162.64           12187.220000
# 19      3  34         3.0     143162.64           12187.220000
# 21      5  34         3.0     143162.64           12187.220000
# 22      6  34         3.0     143162.64           12187.220000
# 23      7  34         3.0     143162.64           12187.220000
# 24      0  54         4.0      30689.89            2612.490833
# 25      1  54         4.0      30689.89            2612.490833
# 26      2  55         4.0      30689.89            2612.490833
# 27      3  55         4.0     30689.89_            2612.490833
# 28      4  55         4.0      30689.89            2612.490833
# 31      7  55         4.0      30689.89            2612.490833
# 42      2  31         6.0      73928.46            5988.705000
# 43      3  31         6.0      73928.46            5988.705000
# 44      4  31         6.0      73928.46            5988.705000
# 45      5  31         6.0      73928.46            5988.705000
# 46      6  31         6.0      73928.46            5988.705000
# 48      0  33         6.0      131313.4           11242.783333
#
#     Num_Bank_Accounts  Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                   3                4              3           4
# 6                   3                4              3           4
# 7                   3                4              3           4
# 17                  1                5              8           3
# 19                  1                5              8           3
# 21                  1                5              8         967
# 22                  1                5              8           3
# 23                  1                5              8           3
# 24                  2                5              4           1
# 25                  2                5              4           1
# 26                  2                5              4           1
# 27                  2                5              4           1
# 28                  2                5              4           1
# 31                  2                5              4        -100
# 42                  4                5              8           0
# 43                  4                5              8           0
# 44                  4                5           5318           0
# 45                  4                5              8           0
# 46                  4                5              8           0
# 48                  0                1              8           2
#
#     Delay_from_due_date  ... Changed_Credit_Limit Num_Credit_Inquiries  \
# 0                     3  ...                11.27                  4.0
# 6                     3  ...                11.27                  4.0
# 7                     3  ...                11.27                  4.0
# 17                   13  ...                  7.1                  3.0
# 19                    8  ...                  9.1                  3.0
# 21                    8  ...                  7.1                  3.0
# 22                    8  ...                  7.1                  3.0
# 23                    8  ...                  7.1                  3.0
# 24                    0  ...                 1.99                  4.0
# 25                    5  ...                 1.99                  4.0
# 26                    3  ...                 1.99                  4.0
# 27                    7  ...                -2.01                  4.0
# 28                    5  ...                -1.01                  4.0
# 31                    4  ...                 1.99                  4.0
# 42                    8  ...                10.14                  2.0
# 43                    8  ...                10.14                  2.0
# 44                   11  ...                10.14                  2.0
# 45                    7  ...                10.14                  2.0
# 46                    8  ...                 9.14                  2.0
# 48                    0  ...                 9.34                  2.0
#
#     Outstanding_Debt Credit_Utilization_Ratio  Payment_of_Min_Amount  \
# 0             809.98                26.822620                     No
# 6             809.98                22.537593                     No
# 7             809.98                23.933795                     No
# 17           1303.01                41.702573                     No
# 19           1303.01                39.501648                     No
# 21           1303.01                39.783993                     No
# 22           1303.01                38.068624                     No
# 23           1303.01                38.374753                     No
# 24            632.46                26.544229                     No
# 25            632.46                35.279982                     No
# 26            632.46                32.301163                     NM
# 27            632.46                38.132348                     No
# 28            632.46                41.154317                     No
# 31            632.46                27.332515                     No
# 42             548.2                40.712187                     No
# 43             548.2                30.201658                     No
# 44             548.2                26.333310                     No
# 45             548.2                35.275437                     No
# 46             548.2                36.624791                     No
# 48            352.16                32.200509                     NM
#
#    Total_EMI_per_month  Amount_invested_monthly Payment_Behaviour  \
# 0            49.574949        80.41529543900253               0.0
# 6            49.574949        178.3440674122349               1.0
# 7            49.574949       24.785216509052056               3.0
# 17          246.992319       232.86038375993544               0.0
# 19          246.992319        825.2162699393922               5.0
# 21          246.992319       257.80809942568976               3.0
# 22          246.992319       263.17416316163934               0.0
# 23          246.992319                __10000__               0.0
# 24           16.415452        81.22885871073616               6.0
# 25           16.415452       124.88181990234848               1.0
# 26           16.415452        83.40650880252501               3.0
# 27           16.415452        272.3340373956682               1.0
# 28           16.415452                __10000__               6.0
# 31           16.415452       125.61725053231268               0.0
# 42            0.000000       150.05973429800815               3.0
# 43            0.000000        618.2023912505837               1.0
# 44            0.000000       177.95183568608738               6.0
# 45        15515.000000       235.79032503182026               6.0
# 46            0.000000        348.5093995125948               0.0
# 48          137.644605        378.1712535207537               3.0
#
#        Monthly_Balance Credit_Score
# 0   312.49408867943663            2
# 6    244.5653167062043            2
# 7   358.12416760938714            1
# 17   998.8692967863226            2
# 19   426.5134106068658            2
# 21   963.9215811205684            2
# 22   968.5555173846187            1
# 23    895.494583180492            1
# 24   433.6047729627723            1
# 25  409.95181177115995            1
# 26  411.42712287098345            1
# 27   262.4995942778403            1
# 28  359.37491550776383            1
# 31  379.21638114119577            1
# 42   698.8107657019921            2
# 43  270.66810874941655            2
# 44   690.9186643139128            2
# 45   633.0801749681799            2
# 46  510.36110048740534            1
# 48    858.462474411158            2
#
# [20 rows x 21 columns]

# %%
train.Month.unique()
# Out:
# array(['January', 'July', 'August', 'February', 'March', 'May', 'June',
#        'April'], dtype=object)

# %%
train['Month'] = \
train['Month'].map({'January':0,'February':1,'March':2,'April':3,'May':4,'June':5,'July':6,'August':7})

# %%
train.head()
# Out:
#    Month  Age Occupation Annual_Income  Monthly_Inhand_Salary  \
# 0      0   23  Scientist      19114.12            1824.843333
# 6      6   23  Scientist      19114.12            1824.843333
# 7      7   23  Scientist      19114.12            1824.843333
# 8      0  28_    _______      34847.84            3037.986667
# 9      1   28    Teacher      34847.84            3037.986667
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                  3                4              3           4
# 6                  3                4              3           4
# 7                  3                4              3           4
# 8                  2                4              6           1
# 9                  2                4              6           1
#
#    Delay_from_due_date  ... Changed_Credit_Limit Num_Credit_Inquiries  \
# 0                    3  ...                11.27                  4.0
# 6                    3  ...                11.27                  4.0
# 7                    3  ...                11.27                  4.0
# 8                    3  ...                 5.42                  2.0
# 9                    7  ...                 7.42                  2.0
#
#    Outstanding_Debt Credit_Utilization_Ratio  Payment_of_Min_Amount  \
# 0            809.98                26.822620                     No
# 6            809.98                22.537593                     No
# 7            809.98                23.933795                     No
# 8            605.03                24.464031                     No
# 9            605.03                38.550848                     No
#
#   Total_EMI_per_month  Amount_invested_monthly  \
# 0           49.574949        80.41529543900253
# 6           49.574949        178.3440674122349
# 7           49.574949       24.785216509052056
# 8           18.816215         104.291825168246
# 9           18.816215        40.39123782853101
#
#                   Payment_Behaviour     Monthly_Balance Credit_Score
# 0   High_spent_Small_value_payments  312.49408867943663            2
# 6    Low_spent_Small_value_payments   244.5653167062043            2
# 7  High_spent_Medium_value_payments  358.12416760938714            1
# 8    Low_spent_Small_value_payments  470.69062692529184            1
# 9   High_spent_Large_value_payments   484.5912142650067            2
#
# [5 rows x 21 columns]

# %%
train.Occupation.unique()
# Out:
# array(['Scientist', '_______', 'Teacher', 'Engineer', 'Entrepreneur',
#        'Developer', 'Lawyer', 'Media_Manager', 'Doctor', 'Journalist',
#        'Manager', 'Accountant', 'Musician', 'Mechanic', 'Writer',
#        'Architect'], dtype=object)

# %%
train['Occupation'] = \
train['Occupation'].map({'Scientist':0, ' _______ ':1, ' Teacher':2, 'Engineer':3, 'Entrepreneur':4,
       ' Developer':5, 'Lawyer':6, ' Media_Manager':7, ' Doctor':8,
       ' Journalist':9, ' Manager':10, ' Accountant':11, ' Musician':12, ' Mechanic':13,
       ' Writer':14, ' Architect':15})

# %%
train.head()
# Out:
#    Month  Age  Occupation Annual_Income  Monthly_Inhand_Salary  \
# 0      0   23         0.0      19114.12            1824.843333
# 6      6   23         0.0      19114.12            1824.843333
# 7      7   23         0.0      19114.12            1824.843333
# 8      0  28_         NaN      34847.84            3037.986667
# 9      1   28         NaN      34847.84            3037.986667
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                  3                4              3           4
# 6                  3                4              3           4
# 7                  3                4              3           4
# 8                  2                4              6           1
# 9                  2                4              6           1
#
#    Delay_from_due_date  ... Changed_Credit_Limit Num_Credit_Inquiries  \
# 0                    3  ...                11.27                  4.0
# 6                    3  ...                11.27                  4.0
# 7                    3  ...                11.27                  4.0
# 8                    3  ...                 5.42                  2.0
# 9                    7  ...                 7.42                  2.0
#
#    Outstanding_Debt Credit_Utilization_Ratio  Payment_of_Min_Amount  \
# 0            809.98                26.822620                     No
# 6            809.98                22.537593                     No
# 7            809.98                23.933795                     No
# 8            605.03                24.464031                     No
# 9            605.03                38.550848                     No
#
#   Total_EMI_per_month  Amount_invested_monthly  \
# 0           49.574949        80.41529543900253
# 6           49.574949        178.3440674122349
# 7           49.574949       24.785216509052056
# 8           18.816215         104.291825168246
# 9           18.816215        40.39123782853101
#
#                   Payment_Behaviour     Monthly_Balance Credit_Score
# 0   High_spent_Small_value_payments  312.49408867943663            2
# 6    Low_spent_Small_value_payments   244.5653167062043            2
# 7  High_spent_Medium_value_payments  358.12416760938714            1
# 8    Low_spent_Small_value_payments  470.69062692529184            1
# 9   High_spent_Large_value_payments   484.5912142650067            2
#
# [5 rows x 21 columns]

# %%
train.Payment_Behaviour.unique()
# Out:
# array(['High_spent_Small_value_payments',
#        'Low_spent_Small_value_payments',
#        'High_spent_Medium_value_payments',
#        'High_spent_Large_value_payments', '!@9#%8',
#        'Low_spent_Medium_value_payments',
#        'Low_spent_Large_value_payments'], dtype=object)

# %%
train['Payment_Behaviour'] = \
train['Payment_Behaviour'].map({'High_spent_Small_value_payments':0,'Low_spent_Small_value_payments':1,
                                'High_spent_Medium_value_payments':2,'High_spent_Medium_value_payments':3,
                                '!@9#%8':4,'Low_spent_Medium_value_payments':5,'Low_spent_Large_value_payments':6})

# %%
train.head()
# Out:
#    Month  Age  Occupation Annual_Income  Monthly_Inhand_Salary  \
# 0      0   23         0.0      19114.12            1824.843333
# 6      6   23         0.0      19114.12            1824.843333
# 7      7   23         0.0      19114.12            1824.843333
# 8      0  28_         NaN      34847.84            3037.986667
# 9      1   28         NaN      34847.84            3037.986667
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                  3                4              3           4
# 6                  3                4              3           4
# 7                  3                4              3           4
# 8                  2                4              6           1
# 9                  2                4              6           1
#
#    Delay_from_due_date  ... Changed_Credit_Limit Num_Credit_Inquiries  \
# 0                    3  ...                11.27                  4.0
# 6                    3  ...                11.27                  4.0
# 7                    3  ...                11.27                  4.0
# 8                    3  ...                 5.42                  2.0
# 9                    7  ...                 7.42                  2.0
#
#    Outstanding_Debt Credit_Utilization_Ratio  Payment_of_Min_Amount  \
# 0            809.98                26.822620                     No
# 6            809.98                22.537593                     No
# 7            809.98                23.933795                     No
# 8            605.03                24.464031                     No
# 9            605.03                38.550848                     No
#
#   Total_EMI_per_month  Amount_invested_monthly Payment_Behaviour  \
# 0           49.574949        80.41529543900253               0.0
# 6           49.574949        178.3440674122349               1.0
# 7           49.574949       24.785216509052056               3.0
# 8           18.816215         104.291825168246               1.0
# 9           18.816215        40.39123782853101               NaN
#
#       Monthly_Balance Credit_Score
# 0  312.49408867943663            2
# 6   244.5653167062043            2
# 7  358.12416760938714            1
# 8  470.69062692529184            1
# 9   484.5912142650067            2
#
# [5 rows x 21 columns]

# %%
train = train.dropna()

# %%
train.head()
# Out:
#     Month Age  Occupation Annual_Income  Monthly_Inhand_Salary  \
# 0       0  23         0.0      19114.12            1824.843333
# 6       6  23         0.0      19114.12            1824.843333
# 7       7  23         0.0      19114.12            1824.843333
# 17      1  34         3.0     143162.64           12187.220000
# 19      3  34         3.0     143162.64           12187.220000
#
#     Num_Bank_Accounts  Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                   3                4              3           4
# 6                   3                4              3           4
# 7                   3                4              3           4
# 17                  1                5              8           3
# 19                  1                5              8           3
#
#     Delay_from_due_date  ... Changed_Credit_Limit Num_Credit_Inquiries  \
# 0                     3  ...                11.27                  4.0
# 6                     3  ...                11.27                  4.0
# 7                     3  ...                11.27                  4.0
# 17                   13  ...                  7.1                  3.0
# 19                    8  ...                  9.1                  3.0
#
#     Outstanding_Debt Credit_Utilization_Ratio  Payment_of_Min_Amount  \
# 0             809.98                26.822620                     No
# 6             809.98                22.537593                     No
# 7             809.98                23.933795                     No
# 17           1303.01                41.702573                     No
# 19           1303.01                39.501648                     No
#
#    Total_EMI_per_month  Amount_invested_monthly Payment_Behaviour  \
# 0            49.574949        80.41529543900253               0.0
# 6            49.574949        178.3440674122349               1.0
# 7            49.574949       24.785216509052056               3.0
# 17          246.992319       232.86038375993544               0.0
# 19          246.992319        825.2162699393922               5.0
#
#        Monthly_Balance Credit_Score
# 0   312.49408867943663            2
# 6    244.5653167062043            2
# 7   358.12416760938714            1
# 17   998.8692967863226            2
# 19   426.5134106068658            2
#
# [5 rows x 21 columns]

# %% [markdown]
# # Korelasi

# %%
#untuk menunjukkan perbandingan data dalam bentuk warna dengan menggunakan data kita atau visualisasi data
sns.heatmap(train.corr())
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(train.corr(),ax=ax,annot=True)
# Out:
# <AxesSubplot:>

# %%
X = train.drop(['Credit_Score'],axis='columns')
X.head()
# Out:
#     Month Age  Occupation Annual_Income  Monthly_Inhand_Salary  \
# 0       0  23         0.0      19114.12            1824.843333
# 6       6  23         0.0      19114.12            1824.843333
# 7       7  23         0.0      19114.12            1824.843333
# 17      1  34         3.0     143162.64           12187.220000
# 19      3  34         3.0     143162.64           12187.220000
#
#     Num_Bank_Accounts  Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                   3                4              3           4
# 6                   3                4              3           4
# 7                   3                4              3           4
# 17                  1                5              8           3
# 19                  1                5              8           3
#
#     Delay_from_due_date Num_of_Delayed_Payment Changed_Credit_Limit  \
# 0                     3                      7                11.27
# 6                     3                     8_                11.27
# 7                     3                      6                11.27
# 17                   13                      6                  7.1
# 19                    8                      5                  9.1
#
#     Num_Credit_Inquiries Outstanding_Debt  Credit_Utilization_Ratio  \
# 0                    4.0           809.98                 26.822620
# 6                    4.0           809.98                 22.537593
# 7                    4.0           809.98                 23.933795
# 17                   3.0          1303.01                 41.702573
# 19                   3.0          1303.01                 39.501648
#
#    Payment_of_Min_Amount  Total_EMI_per_month Amount_invested_monthly  \
# 0                     No            49.574949       80.41529543900253
# 6                     No            49.574949       178.3440674122349
# 7                     No            49.574949      24.785216509052056
# 17                    No           246.992319      232.86038375993544
# 19                    No           246.992319       825.2162699393922
#
#     Payment_Behaviour     Monthly_Balance
# 0                 0.0  312.49408867943663
# 6                 1.0   244.5653167062043
# 7                 3.0  358.12416760938714
# 17                0.0   998.8692967863226
# 19                5.0   426.5134106068658

# %%
y=train.Credit_Score

# %% [markdown]
# # Train tanpa split

# %%
from sklearn.svm import SVC
model_ts = SVC()

# %%
model_ts.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6480\1909114813.py in <module>
# ----> 1 model_ts.fit(X,y)
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     188             check_consistent_length(X, y)
#     189         else:
# --> 190             X, y = self._validate_data(
#     191                 X,
#     192                 y,
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     962         raise ValueError("y cannot be None")
#     963
# --> 964     X = check_array(
#     965         X,
#     966         accept_sparse=accept_sparse,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744                     array = array.astype(dtype, casting="unsafe", copy=False)
#     745                 else:
# --> 746                     array = np.asarray(array, order=order, dtype=dtype)
#     747             except ComplexWarning as complex_warning:
#     748                 raise ValueError(
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    2062
#    2063     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2064         return np.asarray(self._values, dtype=dtype)
#    2065
#    2066     def __array_wrap__(
#
# ValueError: could not convert string to float: '35_'
